# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
import math

# %% [markdown]
# # load dataset of cat vs dogs for now

# %%
IMAGE_HEIGHT = IMAGE_WIDTH = 256
IMAGE_CHANNELS = 3

# dataset = tf.keras.utils.image_dataset_from_directory("./Celeb_images/",
#                                                              label_mode=None,
#                                                                image_size=(IMAGE_HEIGHT, IMAGE_WIDTH),
#                                                                  batch_size=128,
#                                                                  shuffle=True,
#                                                                  color_mode="rgb",
#                                                                  smart_resize=True)

dataset = tf.keras.utils.image_dataset_from_directory("./art_images/monet_jpg/",
                                                            label_mode=None,
                                                              image_size=(IMAGE_HEIGHT, IMAGE_WIDTH),
                                                                batch_size=8,
                                                                shuffle=True,
                                                                color_mode="rgb",
                                                                smart_resize=True)
# Out:
# Found 300 files belonging to 1 classes.
# Metal device set to: Apple M1 Max
#
# systemMemory: 64.00 GB
# maxCacheSize: 24.00 GB

# %% [markdown]
# # GANS
#
# ## steps:
#  - Build an generatr
#  - Build a discriminator
#  - Using both build the GAN
#     - GAN will use the weights of the discriminator to understand how to fool it
#     - We want to optimize both the discriminator and the generator. Both needs to get good at what they do in order to suscceed

# %%
tf.keras.backend.clear_session()

# %% [markdown]
# # Generator
#
# The generator will take a random sample from the latent space and generate an image in this case this could be a text or even audio o some other information format

# %%
# Latent space made out of vectors of 128 positions
LATENT_DIMS = 128

NUMBER_CONVTRASPOSELAYERS = 3

CHANNELS_INIT = 128
GEN_INIT_IMAGE_HEIGHT = GEN_INIT_IMAGE_WIDTH = math.ceil(IMAGE_HEIGHT/(2**NUMBER_CONVTRASPOSELAYERS))

KERNEL_SIZE = 4
STRIDE = 2

X_latent_input = tf.keras.Input(shape=(LATENT_DIMS,))

X = tf.keras.layers.Dense(units=(GEN_INIT_IMAGE_HEIGHT * GEN_INIT_IMAGE_WIDTH * CHANNELS_INIT))(X_latent_input)

X = tf.keras.layers.Reshape((GEN_INIT_IMAGE_HEIGHT, GEN_INIT_IMAGE_WIDTH, CHANNELS_INIT))(X)

for i in range(NUMBER_CONVTRASPOSELAYERS):
    X = tf.keras.layers.Conv2DTranspose(CHANNELS_INIT*(2**i), kernel_size=KERNEL_SIZE, strides=STRIDE, padding="same")(X)
    X = tf.keras.layers.LeakyReLU(alpha=0.2)(X)

X_outputs = tf.keras.layers.Conv2D(IMAGE_CHANNELS, kernel_size=5, padding="same", activation="sigmoid")(X)

generator_model = tf.keras.Model(inputs=X_latent_input, outputs=X_outputs, name="generator")

# %%
generator_model.summary()
# Out:
# Model: "generator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 128)]             0
#
#  dense (Dense)               (None, 131072)            16908288
#
#  reshape (Reshape)           (None, 32, 32, 128)       0
#
#  conv2d_transpose (Conv2DTra  (None, 64, 64, 128)      262272
#  nspose)
#
#  leaky_re_lu (LeakyReLU)     (None, 64, 64, 128)       0
#
#  conv2d_transpose_1 (Conv2DT  (None, 128, 128, 256)    524544
#  ranspose)
#
#  leaky_re_lu_1 (LeakyReLU)   (None, 128, 128, 256)     0
#
#  conv2d_transpose_2 (Conv2DT  (None, 256, 256, 512)    2097664
#  ranspose)
#
#  leaky_re_lu_2 (LeakyReLU)   (None, 256, 256, 512)     0
#
#  conv2d (Conv2D)             (None, 256, 256, 3)       38403
#
# =================================================================
# Total params: 19,831,171
# Trainable params: 19,831,171
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Discriminator
#
# The discriminator is just a simple model that classifies an image in 2 classes Fake or real

# %%
NUMBER_DISCRIMINATOR_CONVLAYERS = 2

INIT_DISCRIMINATOR_FILTERS = 64

X_discriminator_input = tf.keras.Input(shape=(IMAGE_HEIGHT, IMAGE_WIDTH, IMAGE_CHANNELS))

X = tf.keras.layers.Conv2D(filters=INIT_DISCRIMINATOR_FILTERS, kernel_size=KERNEL_SIZE, strides=STRIDE, padding="same")(X_discriminator_input)
X = tf.keras.layers.LeakyReLU(alpha=0.2)(X)

for i in range(NUMBER_CONVTRASPOSELAYERS-1):
    # in the book never changes the filters maybe this is a mistake I gonna keep it for now
    X = tf.keras.layers.Conv2D(filters=INIT_DISCRIMINATOR_FILTERS*2, kernel_size=KERNEL_SIZE, strides=STRIDE, padding="same")(X)
    # X = tf.keras.layers.Conv2D(filters=INIT_DISCRIMINATOR_FILTERS*(2**(i+1)), kernel_size=KERNEL_SIZE, strides=STRIDE, padding="same")(X)
    X = tf.keras.layers.LeakyReLU(alpha=0.2)(X)

X = tf.keras.layers.Flatten()(X)

X = tf.keras.layers.Dropout(0.4)(X)

X_output_real_or_fake = tf.keras.layers.Dense(units=1, activation="sigmoid")(X)

discriminator_model = tf.keras.Model(inputs=X_discriminator_input, outputs=X_output_real_or_fake, name="discriminator")

# %%
discriminator_model.summary()
# Out:
# Model: "discriminator"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 256, 256, 3)]     0
#
#  conv2d_1 (Conv2D)           (None, 128, 128, 64)      3136
#
#  leaky_re_lu_3 (LeakyReLU)   (None, 128, 128, 64)      0
#
#  conv2d_2 (Conv2D)           (None, 64, 64, 128)       131200
#
#  leaky_re_lu_4 (LeakyReLU)   (None, 64, 64, 128)       0
#
#  conv2d_3 (Conv2D)           (None, 32, 32, 128)       262272
#
#  leaky_re_lu_5 (LeakyReLU)   (None, 32, 32, 128)       0
#
#  flatten (Flatten)           (None, 131072)            0
#
#  dropout (Dropout)           (None, 131072)            0
#
#  dense_1 (Dense)             (None, 1)                 131073
#
# =================================================================
# Total params: 527,681
# Trainable params: 527,681
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Adversarial network model
#
# Well this is the complicate part

# %%
class GAN(tf.keras.Model):
    def __init__(self, generator, discriminator, latent_dims, **kwargs):
        super().__init__(**kwargs)
        self.generator = generator
        self.discriminator = discriminator
        # this is to sample a random value from a normal distribution to feed the generator
        self.latent_dims = latent_dims
        self.d_loss_metric = tf.keras.metrics.Mean(name="discriminator_loss")
        self.g_loss_metric = tf.keras.metrics.Mean(name="generator_loss")
    
    def compile(self, d_optimizer, g_optimizer, loss_function, **kwargs):
        """ 
            each model will have its own optimizer
        """
        super(GAN, self).compile()
        self.d_optimizer = d_optimizer
        self.g_optimizer = g_optimizer
        self.loss_function = loss_function

    @property
    def metrics(self):
        return [self.d_loss_metric, self.g_loss_metric]

    def train_step(self, batch_data):
        batch_size = tf.shape(batch_data)[0]

        #generate random a batch of random vectors from a normal distribution of our "latent" space
        # the model is learning
        latent_random_vector = tf.random.normal(shape=(batch_size, self.latent_dims))
        
        batch_of_generated_images = self.generator(latent_random_vector)

        # Now we need to build a dataset with fake and real images with their labels.
        combined_batch_of_images = tf.concat([batch_of_generated_images, batch_data], axis=0)
        
        # the first ones are the fake ones thus all of those are 1 the second one are real thus 0
        labels = tf.concat([tf.ones((batch_size, 1)), tf.zeros((batch_size, 1))], axis=0)

        # this step is a trick it adds noise to the labels a uniform noise
        #TODO: Will this works better with gausian noise added instead?
        labels += 0.05 * tf.random.uniform(shape=tf.shape(labels))

        # Fist optimize the DISCRIMINATOR
        with tf.GradientTape() as tape:
            discriminator_response = self.discriminator(combined_batch_of_images)
            # how good on average the discriminator got spot the fake one vs the real one
            d_loss = self.loss_function(labels, discriminator_response)

        # we are going to use the discriminator weights to update the generator to undestand how to fool it 
        gradients_discriminator = tape.gradient(d_loss, self.discriminator.trainable_weights)
        self.d_optimizer.apply_gradients(zip(gradients_discriminator, self.discriminator.trainable_weights))

        # TODO : May I use the same batch of images already generated?
        #OPTIMIZE THE GENERATOR
        # sample a random vector from the latent space from a normal distribution
        #NO!: I guess for that graph to be capture I need to re do it insie a GradientTape
        sample_random_vector_z = tf.random.normal(shape=(batch_size, self.latent_dims))
        # WHY?
        # this is a way to fool the discriminator to adjust the weights in a way that will be possible to generate images to fool it at leas next time
        misleading_labels = tf.zeros((batch_size, 1))

        with tf.GradientTape() as tape:
            predictions = self.discriminator(self.generator(sample_random_vector_z))
            g_loss = self.loss_function(misleading_labels, predictions)

        # DISCRIMINATOR LOSS over the GENERATOR weights!
        # This is key the Generator is learning how to fool the DISCRIMINATOR!
        gradients_generator = tape.gradient(g_loss, self.generator.trainable_weights)
        self.g_optimizer.apply_gradients(zip(gradients_generator, self.generator.trainable_weights))

        self.d_loss_metric.update_state(d_loss)
        self.g_loss_metric.update_state(g_loss)

        return {"discriminator_loss": self.d_loss_metric.result(),
                "generator_loss": self.g_loss_metric.result()}

# %% [markdown]
# # Callback to see what is going on while training

# %%
class GANMonitor(tf.keras.callbacks.Callback):
    def __init__(self, num_img=3, latent_dim=LATENT_DIMS):
        self.num_img = num_img
        self.latent_dim = latent_dim

    def on_epoch_end(self, epoch, logs=None):
        random_latent_vectors = tf.random.normal(
            shape=(self.num_img, self.latent_dim))
        generated_images = self.model.generator(random_latent_vectors)
        generated_images *= 255 
        generated_images.numpy()
        for i in range(self.num_img):
            img = tf.keras.utils.array_to_img(generated_images[i])
            img.save(f"./gen_gan_images/generated_img_{epoch:03d}_{i}.png")

# %%
tf.keras.backend.clear_session()
gan = GAN(generator=generator_model, discriminator=discriminator_model, latent_dims=LATENT_DIMS)

# %%
gan.compile(d_optimizer = tf.keras.optimizers.legacy.Adam(learning_rate=1e-5), g_optimizer=tf.keras.optimizers.legacy.Adam(learning_rate=1e-4), loss_function=tf.keras.losses.BinaryCrossentropy())

# %%
gan.fit(dataset, epochs=100, callbacks=[GANMonitor(num_img=3, latent_dim=LATENT_DIMS)])
# Out:
# Epoch 1/100
# 2023-05-20 23:12:20.844928: W tensorflow/tsl/platform/profile_utils/cpu_utils.cc:128] Failed to get CPU frequency: 0 Hz
# 38/38 [==============================] - 81s 2s/step - discriminator_loss: 0.6129 - generator_loss: 0.6084
# Epoch 2/100
# 38/38 [==============================] - 79s 2s/step - discriminator_loss: 0.8054 - generator_loss: 0.3114
# Epoch 3/100
# 38/38 [==============================] - 71s 2s/step - discriminator_loss: 1.0776 - generator_loss: 0.1612
# Epoch 4/100
# 38/38 [==============================] - 72s 2s/step - discriminator_loss: 1.1565 - generator_loss: 0.1336
# Epoch 5/100
# 38/38 [==============================] - 71s 2s/step - discriminator_loss: 1.1524 - generator_loss: 0.1378
# Epoch 6/100
# 38/38 [==============================] - 72s 2s/step - discriminator_loss: 1.0645 - generator_loss: 0.1604
# Epoch 7/100
# 38/38 [==============================] - 72s 2s/step - discriminator_loss: 0.9611 - generator_loss: 0.2003
# Epoch 8/100
# 38/38 [==============================] - 72s 2s/step - discriminator_loss: 0.8345 - generator_loss: 0.2618
# Epoch 9/100
# 38/38 [==============================] - 72s 2s/step - discriminator_loss: 0.7124 - generator_loss: 0.3428
# Epoch 10/100
# 38/38 [==============================] - 72s 2s/step - discriminator_loss: 0.6261 - generator_loss: 0.4384
# Epoch 11/100
# 38/38 [==============================] - 71s 2s/step - discriminator_loss: 0.5240 - generator_loss: 0.5531
# Epoch 12/100
# 38/38 [==============================] - 72s 2s/step - discriminator_loss: 0.4455 - generator_loss: 0.6714
# Epoch 13/100
# 38/38 [==============================] - 71s 2s/step - discriminator_loss: 0.3678 - generator_loss: 0.8228
# Epoch 14/100
# 38/38 [==============================] - 71s 2s/step - discriminator_loss: 0.3085 - generator_loss: 0.9902
# Epoch 15/100
# 38/38 [==============================] - 71s 2s/step - discriminator_loss: 0.2630 - generator_loss: 1.1689
# Epoch 16/100
# 38/38 [==============================] - 72s 2s/step - discriminator_loss: 0.2173 - generator_loss: 1.3542
# Epoch 17/100
# 38/38 [==============================] - 71s 2s/step - discriminator_loss: 0.1807 - generator_loss: 1.5382
# Epoch 18/100
# 38/38 [==============================] - 72s 2s/step - discriminator_loss: 0.1648 - generator_loss: 1.6607
# Epoch 19/100
# 38/38 [==============================] - 72s 2s/step - discriminator_loss: 0.2269 - generator_loss: 1.4063
# Epoch 20/100
# 38/38 [==============================] - 72s 2s/step - discriminator_loss: 0.2829 - generator_loss: 1.0742
# Epoch 21/100
# 38/38 [==============================] - 71s 2s/step - discriminator_loss: 0.2608 - generator_loss: 1.1521
# Epoch 22/100
# 38/38 [==============================] - 71s 2s/step - discriminator_loss: 0.2441 - generator_loss: 1.2807
# Epoch 23/100
# 38/38 [==============================] - 71s 2s/step - discriminator_loss: 0.1962 - generator_loss: 1.4495
# Epoch 24/100
# 38/38 [==============================] - 71s 2s/step - discriminator_loss: 0.1984 - generator_loss: 1.6056
# Epoch 25/100
# 38/38 [==============================] - 71s 2s/step - discriminator_loss: 0.1559 - generator_loss: 1.7435
# Epoch 26/100
# 38/38 [==============================] - 72s 2s/step - discriminator_loss: 0.1579 - generator_loss: 1.8218
# Epoch 27/100
# 38/38 [==============================] - 71s 2s/step - discriminator_loss: 0.2019 - generator_loss: 1.7909
# Epoch 28/100
# 38/38 [==============================] - 72s 2s/step - discriminator_loss: 0.2343 - generator_loss: 1.4402
# Epoch 29/100
# 38/38 [==============================] - 72s 2s/step - discriminator_loss: 0.2866 - generator_loss: 1.1840
# Epoch 30/100
# 38/38 [==============================] - 72s 2s/step - discriminator_loss: 0.3736 - generator_loss: 1.0568
# Epoch 31/100
# 38/38 [==============================] - 71s 2s/step - discriminator_loss: 0.4079 - generator_loss: 1.1538
# Epoch 32/100
# 38/38 [==============================] - 71s 2s/step - discriminator_loss: 0.2771 - generator_loss: 1.3239
# Epoch 33/100
# 38/38 [==============================] - 72s 2s/step - discriminator_loss: 0.3002 - generator_loss: 1.4034
# Epoch 34/100
# 38/38 [==============================] - 71s 2s/step - discriminator_loss: 0.2307 - generator_loss: 1.5789
# Epoch 35/100
# 38/38 [==============================] - 71s 2s/step - discriminator_loss: 0.2193 - generator_loss: 1.6841
# Epoch 36/100
# 38/38 [==============================] - 72s 2s/step - discriminator_loss: 0.3153 - generator_loss: 1.6145
# Epoch 37/100
# 38/38 [==============================] - 71s 2s/step - discriminator_loss: 0.2063 - generator_loss: 1.8154
# Epoch 38/100
# 38/38 [==============================] - 72s 2s/step - discriminator_loss: 0.1709 - generator_loss: 1.8577
# Epoch 39/100
# 38/38 [==============================] - 71s 2s/step - discriminator_loss: 0.1590 - generator_loss: 1.8023
# Epoch 40/100
# 38/38 [==============================] - 71s 2s/step - discriminator_loss: 0.1680 - generator_loss: 1.8409
# Epoch 41/100
# 38/38 [==============================] - 72s 2s/step - discriminator_loss: 0.1585 - generator_loss: 1.8883
# Epoch 42/100
# 38/38 [==============================] - 71s 2s/step - discriminator_loss: 0.1483 - generator_loss: 1.9350
# Epoch 43/100
# 38/38 [==============================] - 71s 2s/step - discriminator_loss: 0.1486 - generator_loss: 1.9301
# Epoch 44/100
# 38/38 [==============================] - 71s 2s/step - discriminator_loss: 0.1694 - generator_loss: 1.9381
# Epoch 45/100
# 38/38 [==============================] - 72s 2s/step - discriminator_loss: 0.1855 - generator_loss: 1.9836
# Epoch 46/100
# 38/38 [==============================] - 71s 2s/step - discriminator_loss: 0.1327 - generator_loss: 2.0580
# Epoch 47/100
# 38/38 [==============================] - 71s 2s/step - discriminator_loss: 0.1177 - generator_loss: 2.1827
# Epoch 48/100
# 38/38 [==============================] - 71s 2s/step - discriminator_loss: 0.1153 - generator_loss: 2.2970
# Epoch 49/100
# 38/38 [==============================] - 72s 2s/step - discriminator_loss: 0.1092 - generator_loss: 2.3842
# Epoch 50/100
# 38/38 [==============================] - 72s 2s/step - discriminator_loss: 0.1040 - generator_loss: 2.4555
# Epoch 51/100
# 38/38 [==============================] - 71s 2s/step - discriminator_loss: 0.1019 - generator_loss: 2.5525
# Epoch 52/100
# 38/38 [==============================] - 72s 2s/step - discriminator_loss: 0.1041 - generator_loss: 2.7063
# Epoch 53/100
# 38/38 [==============================] - 71s 2s/step - discriminator_loss: 0.1630 - generator_loss: 2.6403
# Epoch 54/100
# 38/38 [==============================] - 72s 2s/step - discriminator_loss: 0.2309 - generator_loss: 2.5438
# Epoch 55/100
# 38/38 [==============================] - 71s 2s/step - discriminator_loss: 0.1508 - generator_loss: 2.6281
# Epoch 56/100
# 38/38 [==============================] - 72s 2s/step - discriminator_loss: 0.1122 - generator_loss: 2.9149
# Epoch 57/100
# 38/38 [==============================] - 71s 2s/step - discriminator_loss: 0.0820 - generator_loss: 3.0323
# Epoch 58/100
# 38/38 [==============================] - 71s 2s/step - discriminator_loss: 0.0858 - generator_loss: 3.0729
# Epoch 59/100
# 38/38 [==============================] - 72s 2s/step - discriminator_loss: 0.1504 - generator_loss: 3.1341
# Epoch 60/100
# 38/38 [==============================] - 71s 2s/step - discriminator_loss: 0.1122 - generator_loss: 3.1304
# Epoch 61/100
# 38/38 [==============================] - 72s 2s/step - discriminator_loss: 0.0512 - generator_loss: 3.2829
# Epoch 62/100
# 38/38 [==============================] - 72s 2s/step - discriminator_loss: 0.0528 - generator_loss: 3.3896
# Epoch 63/100
# 38/38 [==============================] - 72s 2s/step - discriminator_loss: 0.0435 - generator_loss: 3.5250
# Epoch 64/100
# 38/38 [==============================] - 72s 2s/step - discriminator_loss: 0.0346 - generator_loss: 3.6355
# Epoch 65/100
# 38/38 [==============================] - 72s 2s/step - discriminator_loss: 0.0364 - generator_loss: 3.7394
# Epoch 66/100
# 38/38 [==============================] - 72s 2s/step - discriminator_loss: 0.0297 - generator_loss: 3.8177
# Epoch 67/100
# 38/38 [==============================] - 72s 2s/step - discriminator_loss: 0.0276 - generator_loss: 3.9028
# Epoch 68/100
# 38/38 [==============================] - 71s 2s/step - discriminator_loss: 0.0312 - generator_loss: 4.0179
# Epoch 69/100
# 38/38 [==============================] - 72s 2s/step - discriminator_loss: 0.0264 - generator_loss: 4.1270
# Epoch 70/100
# 38/38 [==============================] - 72s 2s/step - discriminator_loss: 0.0259 - generator_loss: 4.1847
# Epoch 71/100
# 38/38 [==============================] - 71s 2s/step - discriminator_loss: 0.0156 - generator_loss: 4.3075
# Epoch 72/100
# 38/38 [==============================] - 72s 2s/step - discriminator_loss: 0.0454 - generator_loss: 4.3580
# Epoch 73/100
# 38/38 [==============================] - 72s 2s/step - discriminator_loss: 0.0333 - generator_loss: 4.4614
# Epoch 74/100
# 38/38 [==============================] - 71s 2s/step - discriminator_loss: 0.0933 - generator_loss: 4.3495
# Epoch 75/100
# 38/38 [==============================] - 72s 2s/step - discriminator_loss: 0.0684 - generator_loss: 4.4291
# Epoch 76/100
# 38/38 [==============================] - 71s 2s/step - discriminator_loss: 0.0126 - generator_loss: 4.5112
# Epoch 77/100
# 38/38 [==============================] - 71s 2s/step - discriminator_loss: 0.0111 - generator_loss: 4.6790
# Epoch 78/100
# 38/38 [==============================] - 72s 2s/step - discriminator_loss: 0.0060 - generator_loss: 4.8063
# Epoch 79/100
# 38/38 [==============================] - 71s 2s/step - discriminator_loss: 0.0038 - generator_loss: 4.9402
# Epoch 80/100
# 38/38 [==============================] - 72s 2s/step - discriminator_loss: -3.5810e-04 - generator_loss: 5.0580
# Epoch 81/100
# 38/38 [==============================] - 71s 2s/step - discriminator_loss: 6.7425e-04 - generator_loss: 5.1792
# Epoch 82/100
# 38/38 [==============================] - 72s 2s/step - discriminator_loss: 0.0063 - generator_loss: 5.2957
# Epoch 83/100
# 38/38 [==============================] - 72s 2s/step - discriminator_loss: -4.1877e-05 - generator_loss: 5.3317
# Epoch 84/100
# 38/38 [==============================] - 71s 2s/step - discriminator_loss: -0.0041 - generator_loss: 5.4900
# Epoch 85/100
# 38/38 [==============================] - 72s 2s/step - discriminator_loss: -0.0081 - generator_loss: 5.6051
# Epoch 86/100
# 38/38 [==============================] - 71s 2s/step - discriminator_loss: -0.0078 - generator_loss: 5.7552
# Epoch 87/100
# 38/38 [==============================] - 72s 2s/step - discriminator_loss: -0.0076 - generator_loss: 5.8910
# Epoch 88/100
# 38/38 [==============================] - 71s 2s/step - discriminator_loss: -0.0150 - generator_loss: 6.0304
# Epoch 89/100
# 38/38 [==============================] - 72s 2s/step - discriminator_loss: -0.0199 - generator_loss: 6.1918
# Epoch 90/100
# 38/38 [==============================] - 72s 2s/step - discriminator_loss: -0.0192 - generator_loss: 6.3456
# Epoch 91/100
# 38/38 [==============================] - 71s 2s/step - discriminator_loss: 0.0486 - generator_loss: 6.2095
# Epoch 92/100
# 38/38 [==============================] - 72s 2s/step - discriminator_loss: -0.0014 - generator_loss: 6.1268
# Epoch 93/100
# 38/38 [==============================] - 72s 2s/step - discriminator_loss: -0.0217 - generator_loss: 6.5061
# Epoch 94/100
# 38/38 [==============================] - 72s 2s/step - discriminator_loss: -0.0279 - generator_loss: 6.7432
# Epoch 95/100
# 38/38 [==============================] - 71s 2s/step - discriminator_loss: -0.0258 - generator_loss: 6.9444
# Epoch 96/100
# 38/38 [==============================] - 71s 2s/step - discriminator_loss: -0.0254 - generator_loss: 7.1044
# Epoch 97/100
# 38/38 [==============================] - 72s 2s/step - discriminator_loss: -0.0360 - generator_loss: 7.2841
# Epoch 98/100
# 38/38 [==============================] - 73s 2s/step - discriminator_loss: -0.0380 - generator_loss: 7.4733
# Epoch 99/100
# 38/38 [==============================] - 74s 2s/step - discriminator_loss: -0.0359 - generator_loss: 7.6511
# Epoch 100/100
# 38/38 [==============================] - 72s 2s/step - discriminator_loss: 0.0735 - generator_loss: 7.7576
